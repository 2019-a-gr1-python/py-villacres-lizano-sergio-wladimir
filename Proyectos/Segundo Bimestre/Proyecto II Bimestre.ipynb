# %% [markdown]
# # Escuela Politecnica Nacional
# ## Python GR-1
# ## Proyecto segundo bimestre
# ### Nombre: Villacres Lizano Sergio Wladimir

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='C://Users/sergi/Documents/GitHub/py-villacres-lizano-sergio-wladimir/Proyectos/Segundo Bimestre/scrapy_proyecto/tmp/productos-mercado-libre.csv'

# %%
lista = pd.read_csv(
        path
        )

# %%
lista
# Out:
#                       lugar  precio       titulo  vendidos
# 0          Pichincha(Quito)  224.90       Xiaomi     17209
# 1          Pichincha(Quito)  225.00       Xiaomi     20791
# 2          Pichincha(Quito)  225.00       Xiaomi     17826
# 3          Pichincha(Quito)  320.00       Huawei     15788
# 4          Pichincha(Quito)  224.98       Xiaomi     16134
# 5          Pichincha(Quito)  229.95       Xiaomi       332
# 6          Pichincha(Quito)  399.00      Samsung      9709
# 7          Pichincha(Quito)  150.00      Samsung     13696
# 8          Pichincha(Quito)  305.00      Samsung      9659
# 9          Pichincha(Quito)  120.00      Samsung     13998
# 10         Pichincha(Quito)  180.00      Samsung       122
# 11         Pichincha(Quito)  179.99      Samsung        19
# 12         Pichincha(Quito)  270.00      Samsung        48
# 13         Pichincha(Quito)  929.00      Samsung         5
# 14         Pichincha(Quito)  225.00       Huawei     20216
# ...

# %% [markdown]
# **Tema: “Análisis preferencia de compra en celulares - Mercado Libre Ecuador”**
#
# **Objetivos:**
#
# -   Determinar que marca de telefono se vende mas
#
# -   Determinar que sector es el que mas compra en mercado libre
#
# -   Determinar si el precio es un factor importante a la hora de adquirir un dispositivo
#
# -   Determinar si mercado libre cumple con poner primero los articulos mas populares

# %% [markdown]
# ##### Determinar que marca de telefono se vende mas

# %%
p = sns.barplot(x='titulo', y='vendidos', data=lista)

# %% [markdown]
# Analisis: Como se puede observar en el grafico la marca de telefonos que mas se vende es Huawei seguido de Xiaomi y despues samsung, mientras que los que menos se venden son Motorola y Sony Xperia. Esto se puede deber a los precios mas accesibles en estas marcas lo cual comprobaremos mas adelante.

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(lista.groupby(['titulo']).vendidos.sum(),'ko--')
ax.set_title('Ventas por marca')
ax.set_xlabel('Marca')
ax.set_ylabel('Vendidos')
# Out:
# Text(0, 0.5, 'Vendidos')

# %% [markdown]
# Al realizar este nuevo grafico observamos que la marca mas vendida es Samsung seguida de Xiaomi y despues Huawei, la diferencia con la grafica anterior se debe a que esta vez agrupamos los datos y sumamos por marca, lo cual la anterior grafica no representa, en este caso la primera grafica representa el articulo que en una sola publicacion vendio mas por marca.

# %% [markdown]
# ##### Determinar que sector es el que mas compra en mercado libre

# %%
data_gdp = (lista['precio'].groupby(lista['lugar'])).sum()
data_gdp.plot(figsize=(50,20),fontsize=50,color='blue')
plt.xlabel('Lugar', fontsize=50)
plt.ylabel('Precio',fontsize=50)
plt.show()

# %% [markdown]
# Analisis: Este grafico no nos muesta todos los lugares que tenemos en los datos, pero esto se puede deber a que los lugares son tantos que el eje x no puede llenarce completamente

# %%
data = lista['vendidos'].groupby(lista.lugar).mean().sort_values(ascending=False)
f,ax = plt.subplots(1,1,figsize=(15,4))
ax = sns.barplot(data.head(10).index,data.head(10),palette='coolwarm')

# %% [markdown]
# Como podemos observar al obtener el top 10 de los lugares que mas telefonos se venden obtenemos que Quito es la ciudad que mas comercializa telefonos en esta plataforma, esto nos puede ayudar a concluir que el mercado al que va enfocado mercado libre es a Quito.

# %%
data_suicide_mean = lista['precio'].groupby(lista.lugar).mean().sort_values(ascending=False)
f,ax = plt.subplots(1,1,figsize=(15,4))
ax = sns.barplot(data_suicide_mean.head(10).index,data_suicide_mean.head(10),palette='coolwarm')

# %% [markdown]
# Analisis: En esta grafica vemos representado el lugar que mas costoso vende los dispositivos, y esta puede ser una razon importante para analizar el comportamiento de las ventas en relacion al precio.

# %% [markdown]
# ##### Determinar si el precio es un factor importante a la hora de adquirir un dispositivo

# %%
data_suicide_mean = lista['precio'].groupby(lista.titulo).mean().sort_values(ascending=False)
f,ax = plt.subplots(1,1,figsize=(15,4))
ax = sns.barplot(data_suicide_mean.head(10).index,data_suicide_mean.head(10),palette='coolwarm')

# %%
f, ax = plt.subplots(figsize=(15, 10))
ax = sns.regplot(x='precio', y='vendidos',data=lista)
plt.show()

# %% [markdown]
# Analisis: Como se puede ver el primer grafico representa la marca de telefonos mas costosa es iPhone, seguido de samsung, huawei, sony xperia, xiaomi.
# Lo que nos permite concluir con las graficas anteriores que el precio si es un factor importante para determinar que marca de telefono se compra un usuario, por ejemplo la marca Xiaomi tiene fuerza y precencia en los primeros lugares debido a su precio menos al de sus competencias, por otro lado iphone puede representar una gran ganancia sin vender muchas unidades debido a su precio elevado.

# %% [markdown]
# Como ya conosemos que el precio es un factor importante para elegir la marca, con el segundo grafico podemos determinar si el precio es un factor importante para la cantidad de telefonos vendidos. Y como podemos ver esta relacion se cumple ya que a menor precio mas telefonos se vende es decir el rango mas alto esta entre los 200 a 300 dolares

# %% [markdown]
# ##### Determinar si mercado libre cumple con poner primero los articulos mas populares

# %%
g=sns.lineplot(x='lugar', y='vendidos',hue=lista.titulo,data=lista.head(100))

# %% [markdown]
# Analisis: Como pudimos ver en las graficas anteriores el lugar geografico que mas vende telefonos en Quito, y mercado libre conoce esta preferencia ya que para analizarlo tomamos solo los primeros 100 datos para corroborar que el comportamiento no cambie y se concluye que por lugar geografico si cumple.

# %%
p = sns.barplot(x='lugar', y='vendidos', hue='titulo', data=lista.head(100))

# %% [markdown]
# Al ver las graficas anteriores tambien confirmamos las marcas que mas se venden y al hacer una relacion con el lugar geografico podemos determinar que si se cumple esta relacion ya que se toma los 100 primeros datos tomados en orden en la pagina de mercado libre

# %%
f, ax = plt.subplots(figsize=(15, 10))
ax = sns.regplot(x='precio', y='vendidos',data=lista.head(100))
plt.show()

# %% [markdown]
# Por ultimo podemos observar el comportamiento de los vendidos por su precio, para ello se toma los 100 primeros datos ya que estos deberian corresponder al grafico de vendidos en relacion a precio, ya que este nos mostro que los usuarios prefieren telefonos entre los 200 y 300 dolares y mercado libre deberia poner estos primero ya que son mas asequibles para los usuarios.
